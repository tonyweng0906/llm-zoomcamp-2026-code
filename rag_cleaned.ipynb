# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('i just discover the course, can I join right now?')
# Out:
# 'Yes, you can still join right now. If you want a certificate, you need to submit your project while submissions are still open.'
