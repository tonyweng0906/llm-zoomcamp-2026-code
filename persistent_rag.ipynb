# %%
from rag_helper import RAGBase
from ingest import load_faq_data

# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
len(sqlite_index.search(""))
# Out:
# 0

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, openai_client)

# %%
assistant.rag('i just discover the course, can I join right now?')
# Out:
# 'Yes, you can still join right now. If you want a certificate, make sure you submit your project while submissions are still open.'
